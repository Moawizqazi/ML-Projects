# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
animals = pd.read_csv("horse.csv")
animals.head(7)
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
# 5      no  adult           528355          NaN    NaN               NaN
# 6     yes  adult           526802         37.9   48.0              16.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# ...

# %%
target  =  animals["outcome"]

# %%
target.unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
# animals = animals.drop(["outcome"],axis = 1)

# %%
animals.head(2)
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0        died               no    11300        0         0       no
# 1  euthanized               no     2208        0         0       no
#
# [2 rows x 28 columns]

# %%
category_variables = ["surgery", "age", "temp_of_extremities", "peripheral_pulse", "capillary_refill_time",
                       "pain", "peristalsis", "abdominal_distention", "nasogastric_tube", "nasogastric_reflux",
                       "nasogastric_reflux_ph", "rectal_exam_feces", " abdomen", "abdomo_appearance",
                       "surgical_lesion", "cp_data"]

for catogory in category_variables:
    animals[catogory] =pd.get_dummies(animals[catogory])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 6>()
#       1 category_variables = ["surgery", "age", "temp_of_extremities", "peripheral_pulse", "capillary_refill_time",
#       2                        "pain", "peristalsis", "abdominal_distention", "nasogastric_tube", "nasogastric_reflux",
#       3                        "nasogastric_reflux_ph", "rectal_exam_feces", " abdomen", "abdomo_appearance",
#       4                        "surgical_lesion", "cp_data"]
#       6 for catogory in category_variables:
# ----> 7     animals[catogory] =pd.get_dummies(animals[catogory])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3645, in DataFrame.__setitem__(self, key, value)
#    3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
# -> 3645     self._set_item_frame_value(key, value)
#    3646 elif (
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

X = animals.values
y  =  animals["outcome"].values

# %%
lb = LabelEncoder()
y = lb.fit_transform(Y)

# %%
X_train ,X_test , y_train ,y_test  =train_test_split(X,y ,test_size= 0.2 , random_state= 1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
print(X_train.shape)
# Out:
# (239, 29)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan , strategy= "most_frequent")

# %%
X_train = imp.fit_transform(X_train)

X_test = imp.fit_transform(X_test)

# %%
classifier =  DecisionTreeClassifier()

# %%
classifier.fit(X_train,X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 classifier.fit(X_train,X_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# ...
